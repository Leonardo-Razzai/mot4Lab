# %%
from Osc_RS import *

# %%
instr = pd.DataFrame(Lab_Instruments)
instr.transpose()
# Out:
#                      ip_addr           mac_addr
# SA_Rigol        192.168.1.11  00:19:af:52:91:bf
# Osc_RS          192.168.1.12  00:90:b8:28:20:b4
# DMM            192.168.1.107
# FuncGen_Rigol  192.168.1.102  00:19:AF:04:EC:69
# Osc_Rigol

# %%
osc = Osc_RS(channel=1, channel_trigger=3)

# %%
osc.Set_Channel(1)

# %%
osc.Set_vertical_range(3)

# %%
osc.Get_Meas(1)
# Out:
# 0.55338

# %%
x, y = osc.Acquire_and_Get_Data()

import matplotlib.pyplot as plt
plt.plot(x, y)
plt.show()
# Out:
# x_min = -0.6, x_max = 0.599988, record_length = 100000.0
