# %%
from TempAnalyzer import *
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#img_bkg = Image('raw_data/2025-07-17/img/bkg_exp=300us.fits.gz')
img =Image('../raw_data/2025-12-05/img/MOTtest_t_probe=400.fits.gz')
img.select_roi(0, 300, 200, 500)

# %%
img.show_img()

# %%
img.fit_gaussian('x', plot=True)
# Out:
# Number of Atoms = 1.32e+09
# Integral of Gaussian = 1.89e+07, N_tot by diff. = 1.86e+07
# array([1.58761685e+05, 1.00535672e+02, 4.74737112e+01, 1.41685652e+04])

# %%
img.fit_gaussian('y', plot=True)
# Out:
# Number of Atoms = 1.17e+09
# Integral of Gaussian = 1.67e+07, N_tot by diff. = 1.86e+07
# array([1.77633654e+05, 8.69710111e+01, 3.76091947e+01, 2.08328133e+04])
